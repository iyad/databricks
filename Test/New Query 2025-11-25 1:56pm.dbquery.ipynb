-- %%
CREATE STORAGE CREDENTIAL iyad_storage_credential
  WITH AZURE_MANAGED_IDENTITY;
  
CREATE EXTERNAL LOCATION lake_root
  URL 'abfss://databricks@iyaddatabricksstg.dfs.core.windows.net/lake'
  WITH (STORAGE CREDENTIAL iyad_storage_credential);
